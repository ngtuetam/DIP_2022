# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from IPython.display import Image
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import cv2

# %%
image = cv2.imread('../final3.jpg')

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
image.shape
# Out:
# (600, 600, 3)

# %%
pixel_vals = image.reshape((-1,3))

# %%
pixel_vals.shape
# Out:
# (360000, 3)

# %%
pixel_vals = np.float32(pixel_vals)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)

# %%
retval, labels, centers = cv2.kmeans(pixel_vals, 3, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

# %%
centers.shape
# Out:
# (3, 3)

# %%
labels.shape
# Out:
# (360000, 1)

# %%
centers
# Out:
# array([[159.23425 , 104.75512 ,  93.43822 ],
#        [ 36.359894,  55.688576,  21.912554],
#        [227.60262 , 215.61443 , 213.77617 ]], dtype=float32)

# %%
labels = labels.flatten()
labels.shape
# Out:
# (360000,)

# %%
res = centers[labels.flatten()]

# %%
res.shape
# Out:
# (360000, 3)

# %%
result_image = res.reshape((image.shape))

# %%
plt.imshow(result_image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import cv2
import numpy as np
img = cv2.imread("/home/ngtuetam/workspace/XLA-cuoiky-2022/final3.jpg")
b,g,r = cv2.split(img)
plt.imshow(b)
plt.show()

# %%
plt.imshow(g)
plt.show()

# %%
plt.imshow(r)
plt.show()
