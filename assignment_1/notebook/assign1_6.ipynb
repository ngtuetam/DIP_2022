# %% [markdown]
# #### 6) Connected component (25 points)
# - a. Load the image coins.png, using imread(), and show it using imshow().
# - b. Convert the gray-scale image to a binary image
# - c. Find connected components in the binary image. How many connected components do you have? Show the results in your report.

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from PIL import Image

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
img_path ='/home/ngtuetam/workspace/DIP_2022/assignment_1/data/coins.png'

# %%
img_gray = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
img = Image.open(img_path).convert('L')
#img.save('coins_greyscale.png')

# %%
gray_img_path = '/home/ngtuetam/workspace/DIP_2022/assignment_1/notebook/coins_greyscale.png'

# %%
(thresh, binary_img) = cv2.threshold(img_gray, 127, 255, cv2.THRESH_BINARY)

# %%
#cv2.imwrite('coins_binary.png', binary_img)

# %%
binary_img_path = '/home/ngtuetam/workspace/DIP_2022/assignment_1/notebook/coins_binary.png'

# %%
image = cv2.imread(img_path)
image_gray = cv2.imread(gray_img_path)
image_binary = cv2.imread(binary_img_path)

plt.rcParams['figure.figsize'] = [10, 15]
plt.subplot(1,3,1)
plt.imshow(image)
plt.title("Original image")

plt.subplot(1,3,2)
plt.imshow(image_gray)
plt.title("Gray image")

plt.subplot(1,3,3)
plt.imshow(image_binary)
plt.title("Binary image")
# cv2.imshow('Hi', cvim2disp)
# cv2.waitKey(0) 
# cv2.destroyWindow('Hi')
# Out:
# Text(0.5, 1.0, 'Binary image')

# %%
img = cv2.imread('/home/ngtuetam/workspace/DIP_2022/assignment_1/notebook/coins_greyscale.png', 0)
img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)[1]  # ensure binary
num_labels, labels_im = cv2.connectedComponents(img)

# def imshow_components(labels):
#     # Map component labels to hue val
#     label_hue = np.uint8(179*labels/np.max(labels))
#     blank_ch = 255*np.ones_like(label_hue)
#     labeled_img = cv2.merge([label_hue, blank_ch, blank_ch])

#     # cvt to BGR for display
#     labeled_img = cv2.cvtColor(labeled_img, cv2.COLOR_HSV2BGR)

#     # set bg label to black
#     labeled_img[label_hue==0] = 0

#     cv2.imshow('labeled.png', labeled_img)
#     cv2.waitKey(0)
#     cv2.destroyWindow('Hi')

print(num_labels)
# Out:
# 16
