# %% [markdown]
# ### 1. Write your program to produce the negative of the 2_2.bmp image.
# HINT: The negative of an image = (2^n – I)-1, where n is the number of bits and I is
# the intensity value
# of a pixel on this image.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img_path = '/home/ngtuetam/workspace/DIP_2022/assignment_2/images/2_2.bmp'

# %%
img = plt.imread(img_path)
plt.imshow(img)

# %%
img_converted = (2**8 - img)-1

# %%
plt.imshow(img_converted)

# %%
img.dtype   #image 8bit
# Out:
# dtype('uint8')
